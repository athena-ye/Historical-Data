# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import geopy.distance
import seaborn as sns
import glob
import os
import scipy as sci
import scipy.signal as sig
import scipy.spatial as spa
import scipy.stats as stat
from collections import Counter
import random
import math
from joblib import Parallel, delayed
import rpy2.robjects as ro
from rpy2.robjects.packages import importr
from rpy2.robjects import pandas2ri
from rpy2.robjects.conversion import localconverter

ex = './Historical Data/%s.csv'
path = ex % 'LCM'
# !wc -1 $psth
# Out:
# wc: illegal option -- 1
# usage: wc [-clmw] [file ...]

# %%
import rpy2
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr

# %%
base = importr('base')
utils = importr('utils')
stats = importr('stats')

# %%
utils.install_packages('neonUtilities', repos='https://cran.rstudio.com/');
# Out:
# R[write to console]: Installing package into ‘/Users/athenaye/Library/R/4.0/library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/bin/macosx/contrib/4.0/neonUtilities_2.1.3.tgz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 398039 bytes (388 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]:
#
# R[write to console]: downloaded 388 KB
# The downloaded binary packages are in
# 	/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/downloaded_packages

# %%
neonUtilities = importr('neonUtilities')

# %% [markdown]
# # Working function

# %%
stacked = neonUtilities.loadByProduct(dpID= 'DP1.00095.001',
                        site = 'SJER',
                        package='basic',
                        check_size='FALSE',
                        nCores = 4)

# %%
stacked

# %%
with localconverter(ro.default_converter + pandas2ri.converter):
                datainpd = ro.conversion.rpy2py(stacked[3])

# %%
datainpd.columns

# %%
datainpd.to_csv('/Users/athenaye/Desktop/alksd.csv')

# %%
variablelist = ['soilCO2concentrationMean', 'soilCO2concentrationMinimum', 'soilCO2concentrationMaximum',
               'soilCO2concentrationVariance', 'soilCO2concentrationNumPts','soilCO2concentrationStdErMean']
sitelist = ['SERC',
            'SCBI','RMNP','OSBS','ORNL','ONAQ','OAES','NOGP','NIWO','MOAB','MLBS','LENO','LAJA','KONZ','KONA','JORN',
            'JERC','HEAL','HARV','GUAN','GRSM','DSNY','DELA','DEJU','DCFS','CPER','CLBJ','BONA','BLAN','BART','BARR',
            'ABBY']

#'YELL','WREF','WOOD','UNDE','UKFS','TREE','TOOL','TEAK','TALL',
#'STER','STEI','SRER','SOAP','SJER',

# %%
len(sitelist)

# %%
def lbpdataset(slist, dp, variableint, desiredcol):
    for x in range(len(slist)):
        try:
            stacked = neonUtilities.loadByProduct(dpID= dp,
                                    site = slist[x],
                                    package='basic',
                                    check_size='FALSE',
                                    nCores = 4)
            with localconverter(ro.default_converter + pandas2ri.converter):
                    datainpd = ro.conversion.rpy2py(stacked[variableint])
            datainpd['startDateTime'] = datainpd['startDateTime'].astype(str)
            intermediatelist = datainpd["startDateTime"].str.split(' ', n= -1, expand=True)
            datainpd["startDateTime"] = intermediatelist[0]
            for y in range(len(desiredcol)):
                df = pd.DataFrame(datainpd[['siteID', 'startDateTime', desiredcol[y]]])
                df = df.groupby(['siteID','startDateTime'], as_index=False).mean()
                df = pd.melt(df, id_vars=['siteID','startDateTime'], value_vars=[desiredcol[y]])
                df.to_csv('/Users/athenaye/Desktop/steronward/' + str(slist[x]) + str(desiredcol[y]) + '.csv')
        except:
            print('Something went wrong with the site ' + str(slist[x]))

# %%
lbpdataset(sitelist,'DP1.00095.001', 3, variablelist)
# Out:
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3
minute
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~08s           |++                                                | 2 % ~06s           |++                                                | 3 % ~07s           |+++                                               | 4 % ~07s           |+++                                               | 5 % ~07s           |++++                                              | 6 % ~07s           |++++                                              | 7 % ~07s           |+++++                                             | 8 % ~07s           |+++++                                             | 9 % ~07s           |++++++                                            | 10% ~07s           |++++++                                            | 11% ~07s           |+++++++                                           | 12% ~07s           |+++++++                                           | 13% ~07s           |++++++++                                          | 14% ~07s           |++++++++                                          | 15% ~07s           |+++++++++                                         | 16% ~07s           |+++++++++                                         | 18% ~07s           |++++++++++                                        | 19% ~07s           |++++++++++                                        | 20% ~07s           |+++++++++++                                       | 21% ~07s           |+++++++++++                                       | 22% ~07s           |++++++++++++                                      | 23% ~07s           |++++++++++++                                      | 24% ~06s           |+++++++++++++                                     | 25% ~06s           |+++++++++++++                                     | 26% ~06s           |++++++++++++++                                    | 27% ~06s           |++++++++++++++                                    | 28% ~06s           |+++++++++++++++                                   | 29% ~06s           |+++++++++++++++                                   | 30% ~06s           |++++++++++++++++                                  | 31% ~06s           |++++++++++++++++                                  | 32% ~06s           |+++++++++++++++++                                 | 33% ~06s           |++++++++++++++++++                                | 34% ~06s           |++++++++++++++++++                                | 35% ~06s           |+++++++++++++++++++                               | 36% ~06s           |+++++++++++++++++++                               | 37% ~05s           |++++++++++++++++++++                              | 38% ~05s           |++++++++++++++++++++                              | 39% ~05s           |+++++++++++++++++++++                             | 40% ~05s           |+++++++++++++++++++++                             | 41% ~05s           |++++++++++++++++++++++                            | 42% ~05s           |++++++++++++++++++++++                            | 43% ~05s           |+++++++++++++++++++++++                           | 44% ~05s           |+++++++++++++++++++++++                           | 45% ~05s           |++++++++++++++++++++++++                          | 46% ~04s           |++++++++++++++++++++++++                          | 47% ~04s           |+++++++++++++++++++++++++                         | 48% ~04s           |+++++++++++++++++++++++++                         | 49% ~05s           |++++++++++++++++++++++++++                        | 51% ~05s           |++++++++++++++++++++++++++                        | 52% ~05s           |+++++++++++++++++++++++++++                       | 53% ~05s           |+++++++++++++++++++++++++++                       | 54% ~05s           |++++++++++++++++++++++++++++                      | 55% ~05s           |++++++++++++++++++++++++++++                      | 56% ~05s           |+++++++++++++++++++++++++++++         ...
# Merged the most recent publication of sensor position files for each site and saved to /stackedFiles
# Copied the most recent publication of variable definition file to /stackedFiles
# Finished: Stacked 2 data tables and 3 metadata tables!
# Stacking took 2.505484 mins
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.438377991 GB
# Downloading 56 files
#   |======================================================================| 100%
#
# Unpacking zip files using 4 cores.
#   |                                                  | 0 % ~calculating   |++++                                              | 7 % ~10s           |++++++++                                          | 14% ~09s           |+++++++++++                                       | 21% ~08s           |+++++++++++++++                                   | 29% ~07s           |++++++++++++++++++                                | 36% ~06s           |++++++++++++++++++++++                            | 43% ~06s           |+++++++++++++++++++++++++                         | 50% ~05s           |+++++++++++++++++++++++++++++                     | 57% ~04s           |+++++++++++++++++++++++++++++++++                 | 64% ~03s           |++++++++++++++++++++++++++++++++++++              | 71% ~03s           |++++++++++++++++++++++++++++++++++++++++          | 79% ~02s           |+++++++++++++++++++++++++++++++++++++++++++       | 86% ~01s           |+++++++++++++++++++++++++++++++++++++++++++++++   | 93% ~01s           |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed
~23s           |++++++++                                          | 16% ~21s           |+++++++++                                         | 17% ~20s           |++++++++++                                        | 18% ~19s           |++++++++++                                        | 19% ~18s           |+++++++++++                                       | 20% ~17s           |+++++++++++                                       | 21% ~17s           |++++++++++++                                      | 22% ~16s           |++++++++++++                                      | 23% ~15s           |+++++++++++++                                     | 24% ~15s           |+++++++++++++                                     | 26% ~14s           |++++++++++++++                                    | 27% ~14s           |++++++++++++++                                    | 28% ~13s           |+++++++++++++++                                   | 29% ~13s           |+++++++++++++++                                   | 30% ~12s           |++++++++++++++++                                  | 31% ~12s           |++++++++++++++++                                  | 32% ~11s           |+++++++++++++++++                                 | 33% ~11s           |++++++++++++++++++                                | 34% ~10s           |++++++++++++++++++                                | 35% ~10s           |+++++++++++++++++++                               | 36% ~10s           |+++++++++++++++++++                               | 37% ~10s           |++++++++++++++++++++                              | 38% ~09s           |++++++++++++++++++++                              | 39% ~09s           |+++++++++++++++++++++                             | 40% ~09s           |+++++++++++++++++++++                             | 41% ~09s           |++++++++++++++++++++++                            | 43% ~08s           |++++++++++++++++++++++                            | 44% ~08s           |+++++++++++++++++++++++                           | 45% ~08s           |+++++++++++++++++++++++                           | 46% ~08s           |++++++++++++++++++++++++                          | 47% ~07s           |++++++++++++++++++++++++                          | 48% ~07s           |+++++++++++++++++++++++++                         | 49% ~07s           |+++++++++++++++++++++++++                         | 50% ~07s           |++++++++++++++++++++++++++                        | 51% ~06s           |+++++++++++++++++++++++++++                       | 52% ~06s           |+++++++++++++++++++++++++++                       | 53% ~06s           |++++++++++++++++++++++++++++                      | 54% ~06s           |++++++++++++++++++++++++++++                      | 55% ~06s           |+++++++++++++++++++++++++++++                     | 56% ~05s           |+++++++++++++++++++++++++++++                     | 57% ~05s           |++++++++++++++++++++++++++++++        ...
# Merged the most recent publication of sensor position files for each site and saved to /stackedFiles
# Copied the most recent publication of variable definition file to /stackedFiles
# Finished: Stacked 2 data tables and 3 metadata tables!
# Stacking took 2.679369 mins
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.347624664 GB
# Downloading 56 files
#   |======================================================================| 100%
#
# Unpacking zip files using 4 cores.
#   |                                                  | 0 % ~calculating   |++++                                              | 7 % ~20s           |++++++++                                          | 14% ~13s           |+++++++++++                                       | 21% ~10s           |+++++++++++++++                                   | 29% ~09s           |++++++++++++++++++                                | 36% ~07s           |++++++++++++++++++++++                            | 43% ~06s           |+++++++++++++++++++++++++                         | 50% ~05s           |+++++++++++++++++++++++++++++                     | 57% ~05s           |+++++++++++++++++++++++++++++++++                 | 64% ~04s           |++++++++++++++++++++++++++++++++++++              | 71% ~03s           |++++++++++++++++++++++++++++++++++++++++          | 79% ~02s           |+++++++++++++++++++++++++++++++++++++++++++       | 86% ~01s           |+++++++++++++++++++++++++++++++++++++++++++++++   | 93% ~01s           |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=10s
#   |                                                  | 0 % ~calculating   |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=00s
# Parallelizing stacking operation across 4 cores.
# Stacking table SCO2C_1_minute
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % 
|+++++++++++++++                                   | 30% ~07s           |++++++++++++++++                                  | 31% ~06s           |++++++++++++++++                                  | 32% ~06s           |+++++++++++++++++                                 | 33% ~06s           |++++++++++++++++++                                | 34% ~06s           |++++++++++++++++++                                | 35% ~06s           |+++++++++++++++++++                               | 36% ~06s           |+++++++++++++++++++                               | 37% ~06s           |++++++++++++++++++++                              | 38% ~06s           |++++++++++++++++++++                              | 39% ~05s           |+++++++++++++++++++++                             | 40% ~05s           |+++++++++++++++++++++                             | 41% ~05s           |++++++++++++++++++++++                            | 43% ~05s           |++++++++++++++++++++++                            | 44% ~05s           |+++++++++++++++++++++++                           | 45% ~05s           |+++++++++++++++++++++++                           | 46% ~05s           |++++++++++++++++++++++++                          | 47% ~04s           |++++++++++++++++++++++++                          | 48% ~04s           |+++++++++++++++++++++++++                         | 49% ~04s           |+++++++++++++++++++++++++                         | 50% ~04s           |++++++++++++++++++++++++++                        | 51% ~04s           |+++++++++++++++++++++++++++                       | 52% ~04s           |+++++++++++++++++++++++++++                       | 53% ~04s           |++++++++++++++++++++++++++++                      | 54% ~04s           |++++++++++++++++++++++++++++                      | 55% ~04s           |+++++++++++++++++++++++++++++                     | 56% ~04s           |+++++++++++++++++++++++++++++                     | 57% ~04s           |++++++++++++++++++++++++++++++        ...
# Merged the most recent publication of sensor position files for each site and saved to /stackedFiles
# Copied the most recent publication of variable definition file to /stackedFiles
# Finished: Stacked 2 data tables and 3 metadata tables!
# Stacking took 2.464879 mins
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.248183017 GB
# Downloading 55 files
#   |======================================================================| 100%
#
# Unpacking zip files using 4 cores.
#   |                                                  | 0 % ~calculating   |++++                                              | 7 % ~09s           |++++++++                                          | 14% ~08s           |+++++++++++                                       | 21% ~07s           |+++++++++++++++                                   | 29% ~06s           |++++++++++++++++++                                | 36% ~06s           |++++++++++++++++++++++                            | 43% ~05s           |+++++++++++++++++++++++++                         | 50% ~04s           |+++++++++++++++++++++++++++++                     | 57% ~04s           |+++++++++++++++++++++++++++++++++                 | 64% ~03s           |++++++++++++++++++++++++++++++++++++              | 71% ~03s           |++++++++++++++++++++++++++++++++++++++++          | 79% ~02s           |+++++++++++++++++++++++++++++++++++++++++++       | 86% ~01s           |+++++++++++++++++++++++++++++++++++++++++++++++   | 93% ~01s           |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=09s
#   |                                                  | 0 % ~calculating   |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=00s
# Parallelizing stacking operation across 4 cores.
# Stacking table SCO2C_1_minute
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~01m 27s       |++                                                | 2 % ~01m 28s       |++                                                | 3 % ~01m 28s       |+++                                               | 4 % ~01m 26s       |+++                                               | 5 % ~01m 27s       |++++                                              | 7 % ~01m 25s       |++++                                              | 8 % ~01m 23s       |+++++                                             | 9 % ~01m 20s       |+++++                                             | 10% ~01m 18s       |++++++                                            | 11% ~01m 18s       |++++++                                            | 12% ~01m 16s       |+++++++                                           | 13% ~01m 15s       |++++++++                                          | 14% ~01m 15s       |++++++++                                          | 15% ~01m 13s       |+++++++++                                         | 16% ~01m 12s       |+++++++++                                         | 17% ~01m 11s       |++++++++++                                        | 18% ~01m 10s       |++++++
              | 38% ~08s           |++++++++++++++++++++                              | 39% ~08s           |+++++++++++++++++++++                             | 40% ~08s           |+++++++++++++++++++++                             | 41% ~07s           |++++++++++++++++++++++                            | 42% ~07s           |++++++++++++++++++++++                            | 43% ~07s           |+++++++++++++++++++++++                           | 45% ~07s           |+++++++++++++++++++++++                           | 46% ~07s           |++++++++++++++++++++++++                          | 47% ~06s           |++++++++++++++++++++++++                          | 48% ~06s           |+++++++++++++++++++++++++                         | 49% ~06s           |+++++++++++++++++++++++++                         | 50% ~06s           |++++++++++++++++++++++++++                        | 51% ~06s           |+++++++++++++++++++++++++++                       | 52% ~05s           |+++++++++++++++++++++++++++                       | 53% ~05s           |++++++++++++++++++++++++++++                      | 54% ~05s           |++++++++++++++++++++++++++++                      | 55% ~05s           |+++++++++++++++++++++++++++++                     | 57% ~05s           |+++++++++++++++++++++++++++++                     | 58% ~05s           |++++++++++++++++++++++++++++++                    | 59% ~05s           |++++++++++++++++++++++++++++++        ...
# Merged the most recent publication of sensor position files for each site and saved to /stackedFiles
# Copied the most recent publication of variable definition file to /stackedFiles
# Finished: Stacked 2 data tables and 3 metadata tables!
# Stacking took 2.580471 mins
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 2.566891351 GB
# Downloading 42 files
#   |======================================================================| 100%
#
# Unpacking zip files using 4 cores.
#   |                                                  | 0 % ~calculating   |+++++                                             | 9 % ~07s           |++++++++++                                        | 18% ~06s           |++++++++++++++                                    | 27% ~05s           |+++++++++++++++++++                               | 36% ~05s           |+++++++++++++++++++++++                           | 45% ~04s           |++++++++++++++++++++++++++++                      | 55% ~03s           |++++++++++++++++++++++++++++++++                  | 64% ~03s           |+++++++++++++++++++++++++++++++++++++             | 73% ~02s           |+++++++++++++++++++++++++++++++++++++++++         | 82% ~01s           |++++++++++++++++++++++++++++++++++++++++++++++    | 91% ~01s           |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=09s
#   |                                                  | 0 % ~calculating   |++++++++++++++++++++++++++++++++++++++++++++++++++| 100% elapsed=00s
# Parallelizing stacking operation across 4 cores.
# Stacking table SCO2C_1_minute
#   |                                                  | 0 % ~calculating   |+                                                 | 1 % ~42s           |++                                                | 2 % ~42s           |++                                                | 3 % ~43s           |+++                                               | 4 % ~46s           |+++                                               | 6 % ~45s           |++++                                              | 7 % ~46s           |++++                                              | 8 % ~46s           |+++++                                             | 9 % ~46s           |+++++                                             | 10% ~46s           |++++++                                            | 11% ~47s           |+++++++                                           | 12% ~46s           |+++++++                                           | 13% ~45s           |++++++++                                          | 14% ~45s           |++++++++                                          | 16% ~45s           |+++++++++                                         | 17% ~44s           |+++++++++                                         | 18% ~44s           |++++++++++                                        | 19% ~44s           |++++++++++                                        | 20% ~44s           |+++++++++++                                       | 21% ~43s           |++++++++++++                                      | 22% ~43s           |++++++++++++                                      | 23% ~42s           |+++++++++++++                                     | 24% ~42s           |+++++++++++++                                     | 26% ~42s           |++++++++++++++                                    | 27% ~42s           |++++++++++++++                                    | 28% ~41s           |+++++++++++++++                                   | 29% ~40s           |+++++++++++++++                                   | 30% ~39s           |++++++++++++++++                                  | 31% ~38s           |+++++++++++++++++                                 | 32% ~37s           |+++++++++++++++++                                 | 33% ~36s           |++++++++++++++++++                                | 34% ~35s           |++++++++++++++++++                                | 36% ~34s           |+++++++++++++++++++                               | 37% ~33s           |+++++++++++++++++++                               | 38% ~32s           |++++++++++++++++++++                              | 39% ~31s           |++++++++++++++++++++                              | 40% ~30s           |+++++++++++++++++++++                             | 41% ~29s           |++++++++++++++++++++++                            | 42% ~28s           |++++++++++++++++++++++                            | 43% ~27s           |+++++++++++++++++++++++                           | 44% ~26s           |+++++++++++++++++++++++                           | 46% ~25s           |++++++++++++++++++++++++                          | 47% ~24s           |++++++++++++++++++++++++                          | 48% ~23s           |+++++++++++++++++++++++++                         | 49% ~22s           |+++++++++++++++++++++++++                         | 50% ~22s           |++++++++++++++++++++++++++                        | 51% ~21s           |+++++++++++++++++++++++++++                       | 52% ~20s           |+++++++++++++++++++++++++++                       | 53% ~20s           |++++++++++++++++++++++++++++                      | 54% ~20s           |++++++++++++++++++++++++++++                      | 56% ~19s           |+++++++++++++++++++++++++++++                     | 57% ~19s           |+++++++++++++++++++++++++++++                     | 58% ~18s           |++++++++++++++++++++++++++++++                    | 59% ~18s           |++++++++++++++++++++++++++++++                    | 60% ~17s           |+++++++++++++++++++++++++++++++       ...
# Stacking table SCO2C_30_minute
# ...
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316044723/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site JERC
# Finding available files
#   |==========                                                            |  14%
# Rate limit reached. Pausing for 99 seconds to reset.
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.797919906 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316044736', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316044736/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site HEAL
# Finding available files
#   |======================================================================| 100%
#
# Rate limit reached. Pausing for 99 seconds to reset.
#
# Downloading files totaling approximately 3.725626087 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316044931', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316044931/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site HARV
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 2.718943026 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045123', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045123/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site GUAN
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.343730768 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045131', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045131/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site GRSM
# Finding available files
#   |======================================                                |  54%
# Rate limit reached. Pausing for 99 seconds to reset.
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.606643106 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045142', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045142/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site DSNY
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.143608771 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045333', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045333/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site DELA
# Finding available files
#   |==========================                                            |  37%
# Rate limit reached. Pausing for 99 seconds to reset.
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.645656471 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045345', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045345/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site DEJU
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.414363782 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045536', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045536/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site DCFS
# Finding available files
#   |==============================                                        |  42%
# Rate limit reached. Pausing for 99 seconds to reset.
#   |======================================================================| 100%
#
# Downloading files totaling approximately 4.220473714 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045547', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045547/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site CPER
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.357460392 GB
# Downloading 56 files
#   |=                                                                     |   2%
# NEON.D11.CLBJ.DP1.00095.001.2017-07.basic.20220120T173946Z.RELEASE-2022.zip could not be downloaded. Re-attempting.
#
# NEON.D11.CLBJ.DP1.00095.001.2017-07.basic.20220120T173946Z.RELEASE-2022.zip could not be downloaded. URLs may have expired. Refreshing URL list.
# R[write to console]: Error in file(file, if (append) "a" else "w") :
#   cannot open the connection
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: In file(file, if (append) "a" else "w") :
# R[write to console]:
#
# R[write to console]:  cannot open file '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/file895267e958c6': No space left on device
# Something went wrong with the site CLBJ
# Finding available files
#   |======================================================================| 100%
#
# Rate limit reached. Pausing for 99 seconds to reset.
#
# Downloading files totaling approximately 2.979665671 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045814', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316045814/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site BONA
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 3.884614542 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316050004', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316050004/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site BLAN
# Finding available files
#   |======================================================================| 100%
#
# Rate limit reached. Pausing for 99 seconds to reset.
#
# Downloading files totaling approximately 3.677847867 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316050017', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316050017/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site BART
# Finding available files
#   |======================================================================| 100%
#
# Downloading files totaling approximately 2.937549825 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316050209', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316050209/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site BARR
# Finding available files
#   |======================================================================| 100%
#
# Rate limit reached. Pausing for 99 seconds to reset.
#
# Downloading files totaling approximately 3.525700125 GB
# R[write to console]: Error in zipsByProduct(dpID = dpID, site = site, startdate = startdate,  :
#   filesToStack directory could not be created. Check that savepath is a valid directory.
#
# R[write to console]: In addition:
# R[write to console]: Warning messages:
#
# R[write to console]: 1:
# R[write to console]: In dir.create(temppath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316050220', reason 'No space left on device'
#
# R[write to console]: 2:
# R[write to console]: In dir.create(filepath) :
# R[write to console]:
#
# R[write to console]:  cannot create dir '/var/folders/17/5ynsg_xj1rq8f9r_5pc5tgv80000gn/T//RtmpGOOJDZ/zips20220316050220/filesToStack00095', reason 'No such file or directory'
# Something went wrong with the site ABBY

# %%
now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

# %%
names=[]
for e in range(len(variablelist)):
    for l in range(len(sitelist)):
        name = '/Users/athenaye/Desktop/radiation/' + str(sitelist[l]) + str(variablelist[e]) + '.csv'
        names += [name]
    #try:
    combined_csv = pd.concat([pd.read_csv(f) for f in names])
    combined_csv.to_csv('/Users/athenaye/Desktop/' + str(variablelist[e]) + '.csv', index=False )
    #except:
        #print('Something went wrong with the site ' + str(sitelist[l]))

# %%
len(sitelist)

# %% [markdown]
# # 3rd Time Around

# %%
def ziptolongform(stringfilepathofzip):
    stringfilepathofstacked = stringfilepathofzip.replace('.zip', '/stackedFiles')
    neonUtilities.stackByTable(filepath=stringfilepathofzip)
    print(os.listdir(stringfilepathofstacked))
    variable = input('What is the desired observation? ')
    originaldf = pd.read_csv(stringfilepathofstacked + '/' + variable)
    intermediatelist = originaldf["startDateTime"].str.split('T', n= -1, expand=True)
    originaldf["startDateTime"] = intermediatelist[0]
    originaldf = originaldf.set_index(['siteID', 'startDateTime'])
    print(originaldf.columns)
    desiredcolumn = input('What is the desired column? ')
    df = pd.read_csv(stringfilepathofstacked + '/' + variable)
    intermediatelist = df["startDateTime"].str.split('T', n= -1, expand=True)
    df["startDateTime"] = intermediatelist[0]
    df = df[['siteID', 'startDateTime', desiredcolumn]]
    df = df.groupby(['siteID','startDateTime'], as_index=False).mean()
    print(df)
    df = pd.melt(df, id_vars=['siteID','startDateTime'], value_vars=[desiredcolumn])
    del(variable)
    del(originaldf)
    del(intermediatelist)
    return df

# %%
nitratemean = ziptolongform('/Users/athenaye/Desktop/11/NEON_nitrate-surfacewater.zip')

# %%
nitratemean

# %%
nitratemean.to_csv('/Users/athenaye/Desktop/nitratemean.csv')

# %% [markdown]
# # 2nd time around

# %%
master3 = pd.DataFrame()
neonUtilities.stackByTable(filepath='/Users/athenaye/Desktop/12/0/NEON_par.zip')
print(os.listdir('/Users/athenaye/Desktop/12/0/NEON_par/stackedFiles'))
variable = input('What is the desired observation? ')
originaldf = pd.read_csv('//Users/athenaye/Desktop/12/0/NEON_par/stackedFiles/' + variable)
intermediatelist = originaldf["startDateTime"].str.split('T', n= -1, expand=True)
originaldf["startDateTime"] = intermediatelist[0]
originaldf = originaldf.set_index(['siteID', 'startDateTime'])
print(originaldf.columns)
desiredcolumn = input('What is the desired column? ')

x = 1
master3 = pd.DataFrame()
for l in range(len(glob.glob('/Users/athenaye/Desktop/12/*/NEON_par.zip'))-1):
    neonUtilities.stackByTable(filepath='/Users/athenaye/Desktop/12/' + str(x) + '/NEON_par.zip')
    df = pd.read_csv('/Users/athenaye/Desktop/12/' + str(x) + '/NEON_par/stackedFiles/' + variable)
    intermediatelist = df["startDateTime"].str.split('T', n= -1, expand=True)
    df["startDateTime"] = intermediatelist[0]
    df = df[['siteID', 'startDateTime', desiredcolumn]]
    df = df.groupby(['siteID','startDateTime'], as_index=False).mean()
    df = pd.melt(df, id_vars=['siteID','startDateTime'], value_vars=[desiredcolumn])
    master3 = pd.concat([master3, df], axis = 0)
    print(x)
    x += 1

# %%
import sys
def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in locals().items()),
                         key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))

# %%
import sys
def sizeof_fmt(num, suffix='B'):
    ''' by Fred Cirera,  https://stackoverflow.com/a/1094933/1870254, modified'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for name, size in sorted(((name, sys.getsizeof(value)) for name, value in locals().items()),
                         key= lambda x: -x[1])[:10]:
    print("{:>30}: {:>8}".format(name, sizeof_fmt(size)))

# %%
master3

# %%
master2 = pd.DataFrame()
neonUtilities.stackByTable(filepath='/Users/athenaye/Desktop/par-water-surface/0/NEON_par-water-surface.zip')
print(os.listdir('/Users/athenaye/Desktop/par-water-surface/0/NEON_par-water-surface/stackedFiles'))
variable = input('What is the desired observation? ')
originaldf = pd.read_csv('/Users/athenaye/Desktop/par-water-surface/0/NEON_par-water-surface/stackedFiles/' + variable)
intermediatelist = originaldf["startDateTime"].str.split('T', n= -1, expand=True)
originaldf["startDateTime"] = intermediatelist[0]
originaldf = originaldf.set_index(['siteID', 'startDateTime'])
print(originaldf.columns)
desiredcolumn = input('What is the desired column? ')

x = 1
master2 = pd.DataFrame()
for l in range(len(glob.glob('/Users/athenaye/Desktop/par-water-surface/*/NEON_par-water-surface.zip'))-1):
    neonUtilities.stackByTable(filepath='/Users/athenaye/Desktop/par-water-surface/' + str(x) + '/NEON_par-water-surface.zip')
    print(os.listdir('/Users/athenaye/Desktop/par-water-surface/' + str(x) + '/NEON_par-water-surface/stackedFiles'))
    df = pd.read_csv('/Users/athenaye/Desktop/par-water-surface/' + str(x) + '/NEON_par-water-surface/stackedFiles/' + variable)
    intermediatelist = df["startDateTime"].str.split('T', n= -1, expand=True)
    df["startDateTime"] = intermediatelist[0]
    df = df[['siteID', 'startDateTime', desiredcolumn]]
    df = df.groupby(['siteID','startDateTime'], as_index=False).mean()
    df = pd.melt(df, id_vars=['siteID','startDateTime'], value_vars=[desiredcolumn])
    master2 = pd.concat([master2, df], axis = 0)
    x += 1

# %%
master2

# %%
master2.to_csv('/Users/athenaye/Desktop/PARMean.csv')

# %% [markdown]
# # Current Project

# %%
master = pd.DataFrame()
neonUtilities.stackByTable(filepath='/Users/athenaye/Desktop/Trial/0/NEON_elev-surfacewater.zip')
print(os.listdir('/Users/athenaye/Desktop/Trial/0/NEON_elev-surfacewater/stackedFiles'))
variable = input('What is the desired observation? ')
originaldf = pd.read_csv('/Users/athenaye/Desktop/Trial/0/NEON_elev-surfacewater/stackedFiles/' + variable)
intermediatelist = originaldf["startDateTime"].str.split('T', n= -1, expand=True)
originaldf["startDateTime"] = intermediatelist[0]
originaldf = originaldf.set_index(['siteID', 'startDateTime'])
print(originaldf.columns)
desiredcolumn = input('What is the desired column? ')

x = 1
master = pd.DataFrame()
for l in range(len(glob.glob('/Users/athenaye/Desktop/Trial/*/NEON_elev-surfacewater.zip'))-1):
    neonUtilities.stackByTable(filepath='/Users/athenaye/Desktop/Trial/' + str(x) + '/NEON_elev-surfacewater.zip')
    print(os.listdir('/Users/athenaye/Desktop/Trial/' + str(x) + '/NEON_elev-surfacewater/stackedFiles'))
    df = pd.read_csv('/Users/athenaye/Desktop/Trial/' + str(x) + '/NEON_elev-surfacewater/stackedFiles/' + variable)
    intermediatelist = df["startDateTime"].str.split('T', n= -1, expand=True)
    df["startDateTime"] = intermediatelist[0]
    df = df[['siteID', 'startDateTime', desiredcolumn]]
    df = df.groupby(['siteID','startDateTime'], as_index=False).mean()
    df = pd.melt(df, id_vars=['siteID','startDateTime'], value_vars=['surfacewaterElevMean'])
    master = pd.concat([master, df], axis = 0)
    x += 1

# %%
# Normalize
# Does multiindex save space?
# Neon datasets, what would be good ones?
# Get the coordinates for each site (Koppen Climate Classification??)
master

# %%
master.to_csv('/Users/athenaye/Desktop/ElevationSurfaceMean.csv')

# %%
master.iloc[0:500]

# %%
#plt.figure(figsize = (10, 5))
longform = sns.lineplot(y = 'value', x = 'startDateTime', hue = 'siteID', data = master.iloc[0:500])
plt.xlabel('Month')
plt.show()

# %%
#plt.figure(figsize = (10, 5))
longform = sns.lineplot(y = 'value', x = 'startDateTime', hue = 'siteID', data = master.iloc[0:1000])
plt.xlabel('Month')
plt.show()

# %%
#plt.figure(figsize = (10, 5))
longform = sns.lineplot(y = 'value', x = 'startDateTime', hue = 'siteID', data = master.iloc[0:25000])
plt.xlabel('Month')
plt.show()

# %%
#plt.figure(figsize = (10, 5))
longform = sns.lineplot(y = 'value', x = 'startDateTime', hue = 'siteID', data = master)
plt.xlabel('Month')
plt.show()

# %%
pd.melt(master)

# %%
df = pd.read_csv('/Users/athenaye/Desktop/NEON_elev-surfacewater/stackedFiles/EOS_30_min.csv')
intermediatelist = df["startDateTime"].str.split('T', n= -1, expand=True)
df["startDateTime"] = intermediatelist[0]
df = df[['siteID', 'startDateTime', desiredcolumn]]
df = df.groupby(['siteID','startDateTime'], as_index=False).mean()
df = pd.melt(df, id_vars=['siteID','startDateTime'], value_vars=['surfacewaterElevMean'])

# %%
df

# %%
df.index.get_level_values('startDateTime').drop_duplicates()

# %%
df.index = pd.to_datetime(sample.index)

# %%
    neonUtilities.stackByTable(filepath='/Users/athenaye/Desktop/Trial/' + str(x) + '/NEON_elev-surfacewater.zip')
    print(os.listdir('/Users/athenaye/Desktop/Trial/' + str(x) + '/NEON_elev-surfacewater/stackedFiles'))
    df = pd.read_csv('/Users/athenaye/Desktop/Trial/' + str(x) + '/NEON_elev-surfacewater/stackedFiles/' + variable)
    intermediatelist = df["startDateTime"].str.split('T', n= -1, expand=True)
    df["startDateTime"] = intermediatelist[0]
    df = df.set_index(['siteID', 'startDateTime'])
    df = df[[desiredcolumn]]
    siteIDs = df.index.get_level_values('siteID').drop_duplicates()
#     siteIDlist = []
#     for q in range(len(siteIDs)):
#         print(siteIDs[q])
#         siteIDlist += [siteIDs[q]]
    sample = df.xs(siteIDs[z]).groupby('startDateTime').mean()
    sample.index = pd.to_datetime(sample.index)
    sample = sample[[columnname]]
    master = pd.concat([master, df], axis = 0)

# %%
df

# %%
myName = input('What is your name? ')
print("hi" + myName)

# %% [markdown]
# # Past

# %%
allconcat = pd.DataFrame()
for x in range(len(siteIDs)):
    sample = thirty.xs(siteIDs[x]).groupby('startDateTime').mean()
    sample.index = pd.to_datetime(sample.index)
    emptylist = []
    for y in range(len(sample)):
        emptylist += [str(siteIDs[x])]
    sample['site'] = emptylist
    allconcat = pd.concat([allconcat,sample], axis = 0)

# %%
allconcat = pd.DataFrame()
for z in range(len(siteIDs)):
    sample = thirty.xs(siteIDs[z]).groupby('startDateTime').mean()
    sample.index = pd.to_datetime(sample.index)
    sample = sample[['PM15Median']]
    for x in range(len(sample.columns)):
        nonan = sample[sample.columns[x]]
        nonan = nonan.interpolate('time', limit_direction='both')
        a,b = plt.psd(nonan, Fs = 1, scale_by_freq = False, NFFT = 2**14 )
        if x == 0:
            acumulative = a
            bcumulative = b
        else:
            acumulative = np.vstack([acumulative, a])
            bcumulative = np.vstack([bcumulative, b])
        amean = pd.DataFrame(acumulative, index = bcumulative)
        base = sci.interpolate.interp1d(1/amean.index[1:],amean.iloc[1:,0], kind = 'nearest')
        xvalues = np.linspace(1,13, num = 8193, endpoint = True)
        xvalues = xvalues[::-1]
        xvalues = 2**xvalues
        interparray = base(xvalues)
        amean = pd.DataFrame(interparray, index = bcumulative)
        allconcat = pd.concat([allconcat, amean], axis = 1)
allconcat.columns = siteIDlist

# %%
hi = np.array(allconcat.index[1:])
nfftexpnew = 14
interpolated = pd.DataFrame()
for x in range(len(allconcat.columns)):
    base = sci.interpolate.interp1d(1/hi,allconcat.iloc[1:,x], kind = 'nearest')
    xvalues = np.linspace(1,nfftexpnew-1, num = 8193, endpoint = True)
    xvalues = xvalues[::-1]
    xvalues = 2**xvalues
    interparray = base(xvalues)
    series = pd.Series(interparray, index = xvalues)
    interpolated = pd.concat([interpolated, series], axis = 1)
    interpolated.rename_axis('frequency')
    interpolated.rename_axis('measurement', axis='columns')
yvalues = np.array(range(0,8193)) #y-values
xtickmarkloc = [2, 4, 8, 16, 32, 64, 128, 256, 365, 365*2, 365*4, 365*8, 365*16, 8192] #setting the xtickmark locations (numbers represent the period in days)
xtickmarkloc = xtickmarkloc[0:nfftexpnew-1]
x = xvalues #the x-values to interpolate along??
y = yvalues #the y-values to interpolate along??
f = sci.interpolate.interp1d(x, y) #interpolating 
xnew = xtickmarkloc #the desired x-values
ynew = f(xnew) #list of values
interpolated.columns = allconcat.columns
s = sns.heatmap(np.log(interpolated.T), cbar_kws={'label': 'Log of Power Spectral Density'}) #creating the heatmap and labeling the color bar
s.set_title('Power Spectral Density') #setting the heatmap title
s.set_xlabel('Period (days)') #setting the heatmap x-axis label
s.set_ylabel('Measurement') #setting the heatmap x-axis label
newlabel = ['2d', '4d','8d','16d','32d','64d','128d','256d','1yr', '2yr', '4yr', '8yr', '16yr', '8192d'] #setting the x-axis labels
newlabel = newlabel[0:nfftexpnew-1]
plt.xticks(ynew, newlabel) #plotting the x-ticks and the newlabels

# %%
def neontohm(df, columnname, nfft):
    intermediatelist = df["startDateTime"].str.split('T', n= -1, expand=True)
    df["startDateTime"] = intermediatelist[0]
    df = df.set_index(['siteID', 'startDateTime'])
    df = df[[columnname]]
    siteIDs = df.index.get_level_values('siteID').drop_duplicates()
    siteIDlist = []
    for q in range(len(siteIDs)):
        print(siteIDs[q])
        siteIDlist += [siteIDs[q]]
    allconcat = pd.DataFrame()
#     for x in range(len(siteIDs)):
#         sample = df.xs(siteIDs[x]).groupby('startDateTime').mean()
#         sample.index = pd.to_datetime(sample.index)
#         emptylist = []
#         for y in range(len(sample)):
#             emptylist += [str(siteIDs[x])]
#         sample['site'] = emptylist
#         allconcat = pd.concat([allconcat, sample], axis = 0)
    allconcat = pd.DataFrame()
    for z in range(len(siteIDs)):
        sample = df.xs(siteIDs[z]).groupby('startDateTime').mean()
        sample.index = pd.to_datetime(sample.index)
        sample = sample[[columnname]]
        print(sample)
        for x in range(len(sample.columns)):
            nonan = sample[sample.columns[x]]
            nonan = nonan.interpolate('time', limit_direction='both')
            a,b = plt.psd(nonan, Fs = 1, scale_by_freq = False, NFFT = 2**14 )
            if x == 0:
                acumulative = a
                bcumulative = b
            else:
                acumulative = np.vstack([acumulative, a])
                bcumulative = np.vstack([bcumulative, b])
            amean = pd.DataFrame(acumulative, index = bcumulative)
            base = sci.interpolate.interp1d(1/amean.index[1:],amean.iloc[1:,0], kind = 'nearest')
            xvalues = np.linspace(1,13, num = 8193, endpoint = True)
            xvalues = xvalues[::-1]
            xvalues = 2**xvalues
            interparray = base(xvalues)
            amean = pd.DataFrame(interparray, index = bcumulative)
            allconcat = pd.concat([allconcat, amean], axis = 1)
    allconcat.columns = siteIDlist
    hi = np.array(allconcat.index[1:])
    nfftexpnew = 8
    interpolated = pd.DataFrame()
    for x in range(len(allconcat.columns)):
        base = sci.interpolate.interp1d(1/hi,allconcat.iloc[1:,x], kind = 'nearest')
        xvalues = np.linspace(1,nfftexpnew-1, num = 8193, endpoint = True)
        xvalues = xvalues[::-1]
        xvalues = 2**xvalues
        interparray = base(xvalues)
        series = pd.Series(interparray, index = xvalues)
        interpolated = pd.concat([interpolated, series], axis = 1)
        interpolated.rename_axis('frequency')
        interpolated.rename_axis('measurement', axis='columns')
    yvalues = np.array(range(0,8193)) #y-values
    xtickmarkloc = [2, 4, 8, 16, 32, 64, 128, 256, 365, 365*2, 365*4, 365*8, 365*16, 8192] #setting the xtickmark locations (numbers represent the period in days)
    xtickmarkloc = xtickmarkloc[0:nfftexpnew-1]
    x = xvalues #the x-values to interpolate along??
    y = yvalues #the y-values to interpolate along??
    f = sci.interpolate.interp1d(x, y) #interpolating 
    xnew = xtickmarkloc #the desired x-values
    ynew = f(xnew) #list of values
    interpolated.columns = allconcat.columns
    s = sns.heatmap(np.log(interpolated.T), cbar_kws={'label': 'Log of Power Spectral Density'}) #creating the heatmap and labeling the color bar
    s.set_title('Power Spectral Density') #setting the heatmap title
    s.set_xlabel('Period (days)') #setting the heatmap x-axis label
    s.set_ylabel('Barometric Pressure') #setting the heatmap x-axis label
    newlabel = ['2d', '4d','8d','16d','32d','64d','128d','256d','1yr', '2yr', '4yr', '8yr', '16yr', '8192d'] #setting the x-axis labels
    newlabel = newlabel[0:nfftexpnew-1]
    plt.xticks(ynew, newlabel) #plotting the x-ticks and the newlabels

# %%
nitrate

# %%
neontohm(nitrate,'surfWaterNitrateMean', 10 )

# %% [markdown]
# # Break every 10

# %%
from itertools import groupby
from operator import itemgetter

# %%
nitrate = pd.read_csv('/Users/athenaye/Downloads/NEON_nitrate-surfacewater/stackedFiles/NSW_15_minute.csv')

# %%
leco = nitrate.loc[nitrate['siteID'] == 'LEWI']
indexofnan = leco[leco['surfWaterNitrateMean'].isna()].index
indexofnan = indexofnan.to_list()

# %%
siteIDs

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
# Creating dataset
a = []
for x in range(406):
    a.append(1)
for x in range(304):
    a.append(2)
for x in range(84):
    a.append(3)
for x in range(291):
    a.append(4)
for x in range(340):
    a.append(5)
 
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(a, bins = [0.5,1.5,2.5,3.5,4.5,5.5])
 
# Show plot
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Segment')
plt.ylabel('Length of Segment')
plt.title('Length of Each Segment')
plt.show()

# %%
len(listofmaxminnan)/2

# %%
nitrate = pd.read_csv('/Users/athenaye/Downloads/NEON_nitrate-surfacewater/stackedFiles/NSW_15_minute.csv')

intermediatelist = nitrate["startDateTime"].str.split('T', n= -1, expand=True)
nitrate["startDateTime"] = intermediatelist[0]
nitrate = nitrate.set_index(['siteID', 'startDateTime'])
nitrate = nitrate[['surfWaterNitrateMean']]
siteIDs = nitrate.index.get_level_values('siteID').drop_duplicates()
siteIDlist = []
for q in range(len(siteIDs)):
    siteIDlist += [siteIDs[q]]
allconcat = pd.DataFrame()
for z in range(len(siteIDs)):
    sample = nitrate.xs(siteIDs[z]).groupby('startDateTime').mean()
    sample.index = pd.to_datetime(sample.index)
    sample = sample[['surfWaterNitrateMean']]
    plt.plot(sample)
    for x in range(len(sample.columns)):
        nonan = sample[sample.columns[x]]
        nonan = nonan.interpolate('time', limit_direction='both')
        a,b = plt.psd(nonan, Fs = 1, scale_by_freq = False, NFFT = 2**14 )
        if x == 0:
            acumulative = a
            bcumulative = b
        else:
            acumulative = np.vstack([acumulative, a])
            bcumulative = np.vstack([bcumulative, b])
        print(bcumulative)
        amean = pd.DataFrame(acumulative, index = bcumulative)
#         base = sci.interpolate.interp1d(1/amean.index[1:],amean.iloc[1:,0], kind = 'nearest')
#         xvalues = np.linspace(1,13, num = 8193, endpoint = True)
#         xvalues = xvalues[::-1]
#         xvalues = 2**xvalues
#         interparray = base(xvalues)
#         amean = pd.DataFrame(interparray, index = bcumulative)
#         allconcat = pd.concat([allconcat, amean], axis = 1)
# allconcat.columns = siteIDlist
# hi = np.array(allconcat.index[1:])
# nfftexpnew = 8
# interpolated = pd.DataFrame()
# for x in range(len(allconcat.columns)):
#     base = sci.interpolate.interp1d(1/hi,allconcat.iloc[1:,x], kind = 'nearest')
#     xvalues = np.linspace(1,nfftexpnew-1, num = 8193, endpoint = True)
#     xvalues = xvalues[::-1]
#     xvalues = 2**xvalues
#     interparray = base(xvalues)
#     series = pd.Series(interparray, index = xvalues)
#     interpolated = pd.concat([interpolated, series], axis = 1)
#     interpolated.rename_axis('frequency')
#     interpolated.rename_axis('measurement', axis='columns')
# yvalues = np.array(range(0,8193)) #y-values
# xtickmarkloc = [2, 4, 8, 16, 32, 64, 128, 256, 365, 365*2, 365*4, 365*8, 365*16, 8192] #setting the xtickmark locations (numbers represent the period in days)
# xtickmarkloc = xtickmarkloc[0:nfftexpnew-1]
# x = xvalues #the x-values to interpolate along??
# y = yvalues #the y-values to interpolate along??
# f = sci.interpolate.interp1d(x, y) #interpolating 
# xnew = xtickmarkloc #the desired x-values
# ynew = f(xnew) #list of values
# interpolated.columns = allconcat.columns
# s = sns.heatmap(np.log(interpolated.T), cbar_kws={'label': 'Log of Power Spectral Density'}) #creating the heatmap and labeling the color bar
# s.set_title('Power Spectral Density') #setting the heatmap title
# s.set_xlabel('Period (days)') #setting the heatmap x-axis label
# s.set_ylabel('Measurement') #setting the heatmap x-axis label
# newlabel = ['2d', '4d','8d','16d','32d','64d','128d','256d','1yr', '2yr', '4yr', '8yr', '16yr', '8192d'] #setting the x-axis labels
# newlabel = newlabel[0:nfftexpnew-1]
# plt.xticks(ynew, newlabel) #plotting the x-ticks and the newlabels

# %% [markdown]
# # Other Stuff

# %%
intermediatelist = thirty["startDateTime"].str.split('T', n= -1, expand=True)
thirty["startDateTime"] = intermediatelist[0]
thirty = thirty.groupby(siteIDs[x]).mean()

# %%
thirty

# %%
for name in glob.glob('/Users/athenaye/Downloads/NEON_pressure-air/NEON.D10.ARIK.DP1.00004.001.20**-**.basic.20210123T023002Z.RELEASE-2021'):
    endoff = re.sub('.basic.20210123T023002Z.RELEASE-2021', '', name)
    alloff = re.sub('NEON.D10.ARIK.DP1.00004.001.', '', endoff)
    os.rename(name, alloff)

for name in glob.glob('/Users/athenaye/Downloads/NEON_pressure-air/200.000.001.BP_1min.*'):
    alloff = re.sub('200.000.001.BP_1min.', '', name)
    os.rename(name, alloff)

# %%
october2018 = pd.read_csv('./PollenandBird/2018-10', index_col = 'startDateTime')
october2018 = october2018.drop('endDateTime', axis=1)
october2018.index = october2018.index.str.split('T', n= -1, expand=True)
october2018 = october2018.droplevel(1, axis=0)
october2018 = october2018.groupby(october2018.index).mean()
october2018 = october2018['staPresMean']
october2018

# %%
plt.plot(october2018['staPresMean'])

# %%
listoffiles = ['2018-10', '2018-11','2018-12','2019-01','2019-02','2019-03','2019-04','2019-05','2019-06','2019-07','2019-08','2019-09','2019-10','2019-11','2019-12','2020-01','2020-02','2020-03','2020-04','2020-05','2020-06']
listoffiles

# %%
airpressure = pd.DataFrame()
for x in listoffiles:
    nameoffile = './PollenandBird/' + str(x)
    onebyone = pd.read_csv(nameoffile, index_col = 'startDateTime')
    onebyone = onebyone.drop('endDateTime', axis=1)
    onebyone.index = onebyone.index.str.split('T', n= -1, expand=True)
    onebyone = onebyone.droplevel(1, axis=0)
    onebyone = onebyone.groupby(onebyone.index).mean()
    onebyone = onebyone['staPresMean']
    airpressure = pd.concat([airpressure, onebyone], axis = 0)
airpressure.to_csv('./PollenandBird/airpressure.csv')

# %%
airpressure.index = range(len(airpressure))

# %%
plt.plot(airpressure)

# %%
nitrate = pd.read_csv('/Users/athenaye/Downloads/NEON_nitrate-surfacewater/stackedFiles/NSW_15_minute.csv')

# %%
intermediatelist = nitrate["startDateTime"].str.split('T', n= -1, expand=True)
nitrate["startDateTime"] = intermediatelist[0]
nitrate = nitrate.set_index(['siteID', 'startDateTime'])
nitrate = nitrate[['surfWaterNitrateMean']]
siteIDs = nitrate.index.get_level_values('siteID').drop_duplicates()
siteIDlist = []
for q in range(len(siteIDs)):
    print(siteIDs[q])
    siteIDlist += [siteIDs[q]]

# %%
allconcat = pd.DataFrame()
for z in range(len(siteIDs)):
    sample = nitrate.xs(siteIDs[z]).groupby('startDateTime').mean()
    sample.index = pd.to_datetime(sample.index)
    sample = sample[['surfWaterNitrateMean']]
    for x in range(len(sample.columns)):
        nonan = sample[sample.columns[x]]
        nonan = nonan.interpolate('time', limit_direction='both')
        a,b = plt.psd(nonan, Fs = 1, scale_by_freq = False, NFFT = 2**14 )
        if x == 0:
            acumulative = a
            bcumulative = b
        else:
            acumulative = np.vstack([acumulative, a])
            bcumulative = np.vstack([bcumulative, b])
        amean = pd.DataFrame(acumulative, index = bcumulative)
        base = sci.interpolate.interp1d(1/amean.index[1:],amean.iloc[1:,0], kind = 'nearest')
        xvalues = np.linspace(1,13, num = 8193, endpoint = True)
        xvalues = xvalues[::-1]
        xvalues = 2**xvalues
        interparray = base(xvalues)
        amean = pd.DataFrame(interparray, index = bcumulative)
        allconcat = pd.concat([allconcat, amean], axis = 1)
allconcat.columns = siteIDlist
print(allconcat)

# %%
hi = np.array(allconcat.index[1:])
nfftexpnew = 8
interpolated = pd.DataFrame()
for x in range(len(allconcat.columns)):
    base = sci.interpolate.interp1d(1/hi,allconcat.iloc[1:,x], kind = 'nearest')
    xvalues = np.linspace(1,nfftexpnew-1, num = 8193, endpoint = True)
    xvalues = xvalues[::-1]
    xvalues = 2**xvalues
    interparray = base(xvalues)
    series = pd.Series(interparray, index = xvalues)
    interpolated = pd.concat([interpolated, series], axis = 1)
    interpolated.rename_axis('frequency')
    interpolated.rename_axis('measurement', axis='columns')
yvalues = np.array(range(0,8193)) #y-values
xtickmarkloc = [2, 4, 8, 16, 32, 64, 128, 256, 365, 365*2, 365*4, 365*8, 365*16, 8192] #setting the xtickmark locations (numbers represent the period in days)
xtickmarkloc = xtickmarkloc[0:nfftexpnew-1]
x = xvalues #the x-values to interpolate along??
y = yvalues #the y-values to interpolate along??
f = sci.interpolate.interp1d(x, y) #interpolating 
xnew = xtickmarkloc #the desired x-values
ynew = f(xnew) #list of values
interpolated.columns = allconcat.columns
s = sns.heatmap(np.log(interpolated.T), cbar_kws={'label': 'Log of Power Spectral Density'}) #creating the heatmap and labeling the color bar
s.set_title('Power Spectral Density') #setting the heatmap title
s.set_xlabel('Period (days)') #setting the heatmap x-axis label
s.set_ylabel('Measurement') #setting the heatmap x-axis label
newlabel = ['2d', '4d','8d','16d','32d','64d','128d','256d','1yr', '2yr', '4yr', '8yr', '16yr', '8192d'] #setting the x-axis labels
newlabel = newlabel[0:nfftexpnew-1]
plt.xticks(ynew, newlabel) #plotting the x-ticks and the newlabels
